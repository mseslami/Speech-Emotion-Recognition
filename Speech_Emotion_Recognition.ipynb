# %% [markdown]
# <a href="https://colab.research.google.com/github/mseslami/Speech-Emotion-Recognition/blob/master/Speech_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install librosa soundfile numpy sklearn pyaudio
# https://data-flair.training/blogs/python-mini-project-speech-emotion-recognition/#
# !pip install soundfile
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
##############################################################################################################################################################################
##############################################################################################################################################################################
##############################################################################################################################################################################
##############################################################################################################################################################################
##############################################################################################################################################################################
##############################################################################################################################################################################
##############################################################################################################################################################################
##############################################################################################################################################################################
# !pip install IPython
import IPython
import os, glob, pickle
from sklearn.model_selection import train_test_split

import numpy as np
# from scipy.io import wavfile
import wave

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

import re 
import os

# %%
# https://github.com/shaan2909/Emotion-Detection-from-Sound/blob/master/Sound%20Preprocessing%20.ipynb
y, sr = librosa.load('/content/drive/My Drive/RAVDESS/audio/Actor_01/03-01-02-01-02-02-01.wav')
yt,_=librosa.effects.trim(y)
y=yt
print(y.shape, y)

mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=1024, hop_length=100)
mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
librosa.display.specshow(mel_spect, y_axis='mel', fmax=20000, x_axis='time');
#plt.title('Mel Spectrogram');
plt.savefig('x.jpeg')
# Out:
# (50688,) [-5.5350949e-07  4.8694085e-07 -4.1971080e-07 ...  2.7311569e-06
#  -9.4255239e-07 -7.8443736e-07]

# %% [markdown]
# # Task 1:
#
# feature extraction

# %%
dicts={'01' : 'neutral', '02' : 'calm', '03' : 'happy', '04' : 'sad', '05' : 'angry', '06' : 'fearful', '07' : 'disgust', '08' : 'surprised'}
# path_main='Audio_Speech_Actors_01-24'
path_main='/content/drive/My Drive/RAVDESS/audio'
folders_main=os.listdir(path_main)
print(folders_main)
counter=0
for folders in folders_main :
    if folders not in ['Actor_01','Actor_02','Actor_03','Actor_04','Actor_05','Actor_06','Actor_07','Actor_08','Actor_09'
    ,'Actor_10','Actor_11','Actor_12','Actor_13','Actor_14','Actor_','Actor_15','Actor_18','Actor_16','Actor_17','Actor_18','Actor_19','Actor_20','Actor_21','Actor_22','Actor_24']:
      path_in='/content/drive/My Drive/RAVDESS/audio/{0}'.format(folders)
      print(path_in)
      files_sub=os.listdir(path_in)
      for file in files_sub :
          numbers = re.findall('\d+',file)
          emotion=dicts[numbers[2]]
          print(numbers[6],emotion)
          path_save='/content/drive/My Drive/RAVDESS/extracted_features/{0}/{1}.jpeg'.format(emotion,file)
          path_load='{0}/{1}'.format(path_in,file)
          y, sr = librosa.load(path_load)
          yt,_=librosa.effects.trim(y)
          y=yt
          mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=1024, hop_length=100)
          mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
          librosa.display.specshow(mel_spect, y_axis='mel', fmax=20000, x_axis='time');
          plt.savefig(path_save)
# Out:
# ['Actor_02', 'Actor_04', 'Actor_05', 'Actor_03', 'Actor_01', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_11', 'Actor_12', 'Actor_10', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_18', 'Actor_16', 'Actor_17', 'Actor_21', 'Actor_23', 'Actor_20', 'Actor_22', 'Actor_24', 'Actor_19']
# /content/drive/My Drive/RAVDESS/audio/Actor_23
# 23 disgust
# 23 disgust
# 23 disgust
# 23 disgust
# 23 disgust
# 23 disgust
# 23 surprised
# 23 surprised
# 23 surprised
# 23 surprised
# 23 surprised
# 23 surprised
# 23 surprised
# 23 surprised
# 23 neutral
# 23 neutral
# 23 neutral
# 23 neutral
# 23 calm
# 23 calm
# 23 calm
# 23 calm
# 23 calm
# 23 calm
# 23 calm
# 23 calm
# 23 happy
# 23 happy
# 23 happy
# 23 happy
# 23 happy
# 23 happy
# 23 happy
# 23 happy
# 23 sad
# 23 sad
# 23 sad
# 23 sad
# 23 sad
# 23 sad
# 23 sad
# 23 sad
# 23 angry
# 23 angry
# 23 angry
# 23 angry
# 23 angry
# 23 angry
# 23 angry
# 23 angry
# 23 fearful
# 23 fearful
# 23 fearful
# 23 fearful
# 23 fearful
# 23 fearful
# ...

# %% [markdown]
# # task 2:
# image processing
